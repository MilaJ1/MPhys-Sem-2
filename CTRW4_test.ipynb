# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
### Import our Own CTRW Code 
import CTRW_base as CTRW
import CTRW_plot
import CTRW2_mc
import CTRW4
import CTRW4_mc
# %matplotlib notebook

# %%
alpha = 0.5
#D_ends = 2.8e14  # nm^2/s
#D_sites = 2.8e15  #nm^2/s
jump_t = 1e-12  # jump time in s
min_t = 0.001  # minimum waiting time in s
run_t = 86400  # simulation run time in s
delay_t = 2.5  # initial delay time in s
int_length = 25 #nm
separation = 500 #nm

D_site_vals = 2.8*np.logspace(7,14,num=8)
D_end_vals = 2.8*np.logspace(7,14,num=8)

D_end_vals
# Out:
# array([2.8e+07, 2.8e+08, 2.8e+09, 2.8e+10, 2.8e+11, 2.8e+12, 2.8e+13,
#        2.8e+14])

# %%
position = [(0,0,0),(0,0,separation)]
repair_df_De_Ds = CTRW4_mc.ctrw4_De_Ds_mc(1,10, position, D_site_vals,D_end_vals, jump_t, 
                                 run_t, min_t, alpha,int_length, delay_t)
# Out:
# 64
# ----------------
# 0
# 28000000.0 28000000.0
# 1
# 28000000.0 280000000.0
# 2
# 28000000.0 2800000000.0
# 3
# 28000000.0 28000000000.0
# 4
# 28000000.0 280000000000.0
# 5
# 28000000.0 2800000000000.0
# 6
# 28000000.0 28000000000000.0
# 7
# 28000000.0 279999999999999.97
# ----------------
# 8
# 280000000.0 28000000.0
# 9
# 280000000.0 280000000.0
# 10
# 280000000.0 2800000000.0
# 11
# 280000000.0 28000000000.0
# 12
# 280000000.0 280000000000.0
# 13
# 280000000.0 2800000000000.0
# 14
# 280000000.0 28000000000000.0
# 15
# 280000000.0 279999999999999.97
# ----------------
# 16
# 2800000000.0 28000000.0
# 17
# 2800000000.0 280000000.0
# 18
# 2800000000.0 2800000000.0
# 19
# 2800000000.0 28000000000.0
# 20
# 2800000000.0 280000000000.0
# 21
# 2800000000.0 2800000000000.0
# 22
# 2800000000.0 28000000000000.0
# 23
# 2800000000.0 279999999999999.97
# ----------------
# 24
# 28000000000.0 28000000.0
# 25
# 28000000000.0 280000000.0
# 26
# 28000000000.0 2800000000.0
# 27
# 28000000000.0 28000000000.0
# 28
# 28000000000.0 280000000000.0
# 29
# 28000000000.0 2800000000000.0
# 30
# 28000000000.0 28000000000000.0
# 31
# 28000000000.0 279999999999999.97
# ----------------
# 32
# 280000000000.0 28000000.0
# 33
# 280000000000.0 280000000.0
# 34
# 280000000000.0 2800000000.0
# 35
# 280000000000.0 28000000000.0
# 36
# 280000000000.0 280000000000.0
# 37
# 280000000000.0 2800000000000.0
# 38
# 280000000000.0 28000000000000.0
# 39
# 280000000000.0 279999999999999.97
# ----------------
# 40
# 2800000000000.0 28000000.0
# 41
# 2800000000000.0 280000000.0
# 42
# 2800000000000.0 2800000000.0
# 43
# 2800000000000.0 28000000000.0
# 44
# 2800000000000.0 280000000000.0
# 45
# 2800000000000.0 2800000000000.0
# 46
# 2800000000000.0 28000000000000.0
# 47
# 2800000000000.0 279999999999999.97
# ----------------
# 48
# 28000000000000.0 28000000.0
# 49
# 28000000000000.0 280000000.0
# 50
# 28000000000000.0 2800000000.0
# 51
# 28000000000000.0 28000000000.0
# 52
# 28000000000000.0 280000000000.0
# 53
# 28000000000000.0 2800000000000.0
# 54
# 28000000000000.0 28000000000000.0
# 55
# 28000000000000.0 279999999999999.97
# ----------------
# 56
# 279999999999999.97 28000000.0
# 57
# 279999999999999.97 280000000.0
# 58
# 279999999999999.97 2800000000.0
# 59
# 279999999999999.97 28000000000.0
# 60
# 279999999999999.97 280000000000.0
# 61
# 279999999999999.97 2800000000000.0
# 62
# 279999999999999.97 28000000000000.0
# 63
# 279999999999999.97 279999999999999.97

# %%
#CTRW_plot.heatmap_repair_misrepair_subplots(repair_df_De_Ds,8,8,misrep_multiplier=1,
 #                                   extent_list=[2.8e7,2.8e14,2.8e7,2.8e14])
repair_df_De_Ds.to_csv('De_7_14_Ds_7_14_m8_r10_min_t.csv')
De_7_14_Ds_7_14_m8_r10_min_t = pd.read_csv('De_7_14_Ds_7_14_m8_r10_min_t.csv')
CTRW_plot.plot_De_and_Ds_subplots(De_7_14_Ds_7_14_m8_r10_min_t,plot_dim_1=2,plot_dim_2=4)
# Out:
# <img src="data:image/png;base64,..." width="1600">
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
