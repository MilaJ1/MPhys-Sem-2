# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
### Import our Own CTRW Code 
import CTRW_base as CTRW
import CTRW_plot
import CTRW2_mc
import CTRW4
import CTRW4_mc
# %matplotlib notebook

# %%
alpha = 0.5
jump_t = 1e-12  # jump time in s
min_t = 0.001  # minimum waiting time in s
run_t = 86400  # simulation run time in s
delay_t = 2.5  # initial delay time in s
int_length = 25 #nm
separation = 500 #nm
position = [(0,0,0),(0,0,separation)]

D_site_vals = np.logspace(10,17,num=8)
D_end_vals = np.logspace(10,17,num=8)

# %%
#repair_df_De_Ds = CTRW4_mc.ctrw4_De_Ds_mc(1,500, position, D_site_vals,D_end_vals, jump_t, 
 #                                run_t, min_t, alpha,int_length, delay_t)

# %%
#filename = 'De_10_17_Ds_10_17_m8_r10_wfile.csv'
#CTRW4_mc.ctrw4_De_Ds_mc(1,10, position, D_site_vals,D_end_vals, jump_t, 
 #                               run_t, min_t, alpha,int_length, delay_t,filename=filename)

# %%
#CTRW_plot.heatmap_repair_misrepair_subplots(repair_df_De_Ds,8,8,misrep_multiplier=1,
 #                                   extent_list=[2.8e7,2.8e14,2.8e7,2.8e14])
#repair_df_De_Ds.to_csv('De_12_13_Ds_10_17_m8_r500_min_t.csv')
#De_13_14_Ds_13_14_m10_r50_min_t = pd.read_csv('De_13_14_Ds_13_14_m10_r50_min_t.csv')
De_12_13_Ds_10_17_m8_r500_min_t = pd.read_csv('De_12_13_Ds_10_17_m8_r500_min_t.csv')
De_10_17_Ds_10_17_m8_r10_min_t = pd.read_csv('De_10_17_Ds_10_17_m8_r10_wfile.csv')

# %%
CTRW_plot.plot_De_and_Ds_subplots(De_10_17_Ds_10_17_m8_r10_min_t,plot_dim_1=2,plot_dim_2=4,reps=10)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
De_10_17_Ds_10_17_m8_r10_min_t
# Out:
#           D_ends       D_sites  Repair Rate  Repair Rate Std  Misrepair Rate  \
# 0   1.000000e+10  1.000000e+10          1.0              0.0             0.0
# 1   1.000000e+10  1.000000e+11          1.0              0.0             0.0
# 2   1.000000e+10  1.000000e+12          1.0              0.0             0.0
# 3   1.000000e+10  1.000000e+13          1.0              0.0             0.0
# 4   1.000000e+10  1.000000e+14          1.0              0.0             0.0
# ..           ...           ...          ...              ...             ...
# 59  1.000000e+17  1.000000e+13          0.0              0.0             0.1
# 60  1.000000e+17  1.000000e+14          0.0              0.0             0.0
# 61  1.000000e+17  1.000000e+15          0.1              0.3             0.0
# 62  1.000000e+17  1.000000e+16          0.0              0.0             0.0
# 63  1.000000e+17  1.000000e+17          0.0              0.0             0.0
#
#     Misrepair Rate Std
# ...

# %%
CTRW_plot.heatmap_repair_misrepair_subplots(De_10_17_Ds_10_17_m8_r10_min_t,
                                            8,8,misrep_multiplier=1,extent_list=[10,17,10,17])
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
CTRW_plot.heatmap_repair_misrepair_subplots(De_12_13_Ds_10_17_m8_r500_min_t,
                                            8,8,misrep_multiplier=1,extent_list=[10,17,12,13])
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
alpha = 0.5
jump_t = 1e-12  # jump time in s
min_t = 0.001  # minimum waiting time in s
run_t = 86400  # simulation run time in s
#delay_t = 2.5  # initial delay time in s
int_length = 25 #nm
separation = 500 #nm

init_pos = [(0,0,0),(0,0,separation)]

delay_ts = np.array([0.5,2.5,5,10,25,100])
d_site_coeffs = 2.8*np.logspace(9,17,num=17)

# %%
repair_df_delay_t_Ds = CTRW4_mc.ctrw4_delay_t_Ds_mc(1,100,init_pos,delay_ts, d_site_coeffs, jump_t, 
                        run_t, min_t, alpha,int_length)#,D_end=2.8e11,interaction_p=1):
# Out:
# 102
# ----------------
# 0
# 0.5 2800000000.0
# 1
# 0.5 8854377448.471462
# 2
# 0.5 28000000000.0
# 3
# 0.5 88543774484.71461
# 4
# 0.5 280000000000.0
# 5
# 0.5 885437744847.1462
# 6
# 0.5 2800000000000.0
# 7
# 0.5 8854377448471.46
# 8
# 0.5 28000000000000.0
# 9
# 0.5 88543774484714.61
# 10
# 0.5 279999999999999.97
# 11
# 0.5 885437744847146.1
# 12
# 0.5 2800000000000000.0
# 13
# 0.5 8854377448471462.0
# 14
# 0.5 2.8e+16
# 15
# 0.5 8.854377448471461e+16
# 16
# 0.5 2.7999999999999997e+17
# ----------------
# 17
# 2.5 2800000000.0
# 18
# 2.5 8854377448.471462
# 19
# 2.5 28000000000.0
# 20
# 2.5 88543774484.71461
# 21
# 2.5 280000000000.0
# 22
# 2.5 885437744847.1462
# 23
# 2.5 2800000000000.0
# 24
# 2.5 8854377448471.46
# 25
# 2.5 28000000000000.0
# 26
# 2.5 88543774484714.61
# 27
# 2.5 279999999999999.97
# 28
# 2.5 885437744847146.1
# 29
# 2.5 2800000000000000.0
# 30
# 2.5 8854377448471462.0
# 31
# 2.5 2.8e+16
# 32
# 2.5 8.854377448471461e+16
# 33
# 2.5 2.7999999999999997e+17
# ...

# %%
repair_df_delay_t_Ds.to_csv('repair_df_delay_t_0.5_100_Ds_9_17_m17_r100')
repair_df_delay_t_Ds = pd.read_csv('repair_df_delay_t_0.5_100_Ds_10_18_m20_r10')

# %%
CTRW4_mc.print_full(repair_df_delay_t_Ds)
# Out:
#      Unnamed: 0           Delay Time                      D_sites          Repair Rate      Repair Rate Std       Misrepair Rate   Misrepair Rate Std
# 0             0                 0.50            28,000,000,000.00                 1.00                 0.00                 0.00                 0.00
# 1             1                 0.50            88,543,774,484.71                 1.00                 0.00                 0.00                 0.00
# 2             2                 0.50           280,000,000,000.00                 1.00                 0.00                 0.00                 0.00
# 3             3                 0.50           885,437,744,847.15                 1.00                 0.00                 0.00                 0.00
# 4             4                 0.50         2,800,000,000,000.00                 1.00                 0.00                 0.00                 0.00
# ...
